# %% [markdown]
# # Programming Task :  Basic Python Programming

# %% [markdown]
# ### Question 1. Say 'Hello, World' with Pyhton

# %%
my_string = 'Hello, World!'
print(my_string)
# Out:
# Hello, World!

# %% [markdown]
# ### Question 2. if- else statements

# %% [markdown]
# **Given an integer, , perform the following conditional actions:**
#
# - If n is odd, print Weird
# - If n is even and in the inclusive range of 2 to 5, print Not Weird
# - If n is even and in the inclusive range of 6 to 20, print Weird
# - If n is even and greater than 20, print Not Weird

# %%
def check_number(n):
    if n % 2 != 0:
        print('Weird')
    elif 2 <= n <= 5:
        print('Not Weird')
    elif 6 <= n <= 20:
        print('Wired')
    elif n > 20:
        print('Not Wired')
n = int(input().strip())
check_number(n)
# Out:
#  2
# Not Weird

# %%
check_number(4)
check_number(10)
check_number(3)
check_number(15)
check_number(1)
check_number(35)
check_number(36)
# Out:
# Not Weird
# Wired
# Weird
# Weird
# Weird
# Weird
# Not Wired

# %% [markdown]
# ### Question 3. Arithmatic operators

# %% [markdown]
# - The provided code stub reads two integers from STDIN, a and b. Add code to print three lines where:
#
# - The first line contains the sum of the two numbers.
# - The second line contains the difference of the two numbers (first - second).
# - The third line contains the product of the two numbers

# %%
a = 3
b = 2

print(f'Sum: {a + b}')
print(f'Differnece: {a - b}')
print(f'Product: {a * b}')
# Out:
# Sum: 5
# Differnece: 1
# Product: 6

# %% [markdown]
# ### Question 4, Python: Division

# %% [markdown]
# - The provided code stub reads two integers,a  and b, from STDIN.
#
# - Add logic to print two lines. The first line should contain the result of integer division,a  // b . The second line should contain the result of float division,a  / b .
#
# - No rounding or formatting is necessary.

# %%
a = 4
b = 3

print(f'Integer Division: {a // b}')
print(f'Float Divison: {a / b}')
# Out:
# Integer Division: 1
# Float Divison: 1.3333333333333333

# %% [markdown]
# ### Question 5.  LOOPS

# %% [markdown]
#  - The provided code stub reads an integer,n, from STDIN. For all non-negative integers i>n, print i .

# %%
n = int(input())

for i in range(n):
    print(f'{i} squared is {i**2}')
# Out:
#  4
# 0 squared is 0
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %% [markdown]
# ### Question 6. Write a Function

# %% [markdown]
# An extra day is added to the calendar almost every four years as February 29, and the day is called a leap day. It corrects the calendar for the fact that our planet takes approximately 365.25 days to orbit the sun. A leap year contains a leap day.
#
# In the Gregorian calendar, three conditions are used to identify leap years:
#
# The year can be evenly divided by 4, is a leap year, unless:
# The year can be evenly divided by 100, it is NOT a leap year, unless:
# The year is also evenly divisible by 400. Then it is a leap year.
# This means that in the Gregorian calendar, the years 2000 and 2400 are leap years, while 1800, 1900, 2100, 2200, 2300 and 2500 are NOT leap years. Source
#
# Task
#
# Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.
#
# Note that the code stub provided reads from STDIN and passes arguments to the is_leap function. It is only necessary to complete the is_leap function.

# %%
def is_leap(year):
    # Return True if (divisible by 400) OR (divisible by 4 AND NOT by 100)
    return (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0)

# Test Logic
print(f"2000: {is_leap(2000)}")  # Should be True
print(f"2400: {is_leap(2400)}")  # Should be True
print(f"1900: {is_leap(1900)}")  # Should be False
print(f"2024: {is_leap(2024)}")  # Should be True
# Out:
# 2000: True
# 2400: True
# 1900: False
# 2024: True

# %% [markdown]
# ### Question 7. loops

# %% [markdown]
# - The included code stub will read an integer,n, from STDIN.
# - Without using any string methods, try to print the following:
# - 1234....n
# - Note that "....." represents the consecutive values in between.

# %%
n=5
print(*range(1, n + 1), sep="")
# Out:
# 12345
